# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7c64df02-b926-4217-a9a9-b1439167e14d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c64df02-b926-4217-a9a9-b1439167e14d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ejemplo de la clase.xlsx to ejemplo de la clase.xlsx
# User uploaded file "ejemplo de la clase.xlsx" with length 8723 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('EjemploSemanaTec.txt', 'w') as f:
  f.write('ejemplo de la clase')

files.download('EjemploSemanaTec.txt')

# %%
ls
# Out:
# 'ejemplo de la clase.xlsx'   EjemploSemanaTec.txt   sample_data/

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/SemanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/SemanaTec/foo.txt
# Out:
# Hello Google Drive!

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: 2.1 - Básicos de Unix y GIT.ipynb, id: 1V05fLDIgKg2gCITYYoqBQG3klIU46zu1
# title: SemanaTec, id: 1_w6DM-SKyShdLXyOGmdjw2xtO2oCuh-p
# title: arte-analitica-main.zip, id: 1Z4-EBfshEm8dSrobD-_UgAiB-F7Sr7tU
# title: Reto de sistema de flujos, id: 1e1UKiftFQFzQmS-XmdSLCh-1BIYhNn-HiSkry2t5ziI
# title: Copia de Water Resources Business Plan by Slidesgo
# title: IMG_4181.JPG, id: 1LqP3HYB5gOW9KTh-U1efRJOxBVULq_no
# title: IMG_4182.JPG, id: 1EfONon0HyUeJf3j1FBizdEvIjW0oVYB3
# title: IMG_4178.JPG, id: 1tEpvBJdGGqhbp-RBnUi_uaG99bM52zhz
# title: IMG_4180.JPG, id: 16WijcSzys3wtj8YupKqar7CMO6iTLruk
# title: IMG_4177.JPG, id: 1uuVO70PHoBrbRqj7drSLv_svlyVg8oI-
# title: IMG_4175.JPG, id: 1PgbIxPMQ6o42BLTHDQl4L56YVK4ZAOwi
# title: IMG_4176.JPG, id: 1dNCeNSB6CjecIPp3v1vkovM030IjQ57Z
# title: IMG_4174.PNG, id: 1gurFN4toBnoMrnAQO0j88aJ0kjUVyKAk
# title: Final Pryect Math.pptx, id: 1JFLDAaiF-OVZVGkE1DTnrCZ_WZxSDHhThSWfvHbW37U
# title: Final Pryect Math.pptx, id: 1RB63IO9WfcjTcsSvx8HELLo0C3ePKpgy
# title: Final Proyect math, id: 1piIs_DGSjjS0LkUwkos8O-z5B-Kat0VLE2uHH8-ErE4
# title: Final Pryect Math, id: 15uiBc8TjjubVnnmO6nnc45vo2DO7wbRKP1FLYIn_eeU
# title: Final Pryect Math, id: 1eXvis0Xm9Tx-qdwiKlJFV0b5fnO9-XQw72dz00xoxTY
# title: Colligative properties, id: 1gsDI0xaZTvt4rcAHBmpghxA0D8DjNzXMBK2koPeq1ok
# title: Internet and Technology, id: 1cvfc2YqpL6N8cGmC7Fb6UL9Iq53up7reKEbsEjJA2s0
# title: Moles(1).pptx, id: 0Byqwa9BQPtt3dUZUbGtpU0hTeWM
# title: caso planificación familiar parcial 2, id: 1jIN9PNO2-_eQYQ3c1fwFYTVKa3tgPYoa-rB6xSz6qXU
# title: Chernobyl Project , id: 1JCdwmyM9tAxhFwNDWBac5xB29DRM9aSLuN3c1Zl-G_w
# title: Untitled document, id: 1C9hQ4AwC_l9zOfTAeOq5EMxE9kFotd-mMwQsFFpX4fI
# title: Aleman, id: 1P-ToQ-0LJb2046tp-sZyllmUSEXnJmY8WP-pQ42wRdU
# title: Real GDP, id: 1CmH8A32Y610Wx-BJvDxGd2hFRSm4eJMnRB8uym8qDUU
# title: WTO, id: 1uj1oxv3pbc7DnFPcugh0OrAdqZ_JxDr_XzWdHdRmBzY
# title: Frecuencia Jupiter , id: 1i-BRnumOjGC2iDKlXkEcz_4x4cFLVDji4YcQahxQ5ow
# title: Etica proyecto  , id: 1BttHrI9BiwP7InU8iCOvnh0qvV6QUcI6WLg9VBlOTUk
# title: Migration, id: 1d_pxjSgyeRMkovqUYceGz-Hfg1bcqcxt1-3p3JsTGJc
# title: Aleman, id: 17lHthMdCr8vJtJNmpJQyyzD3b4A4Wknecs2eJ6R53kA
# title: Math 3, id: 0Byqwa9BQPtt3Q3cxUUZQYVEyOEk
# title: PLC. P1_S3 Input_Process_Ouput, id: 1xFEkpAHKB6CWSGlzS4VnNJAymojHYGLrPGgm2U28V4o
# title: input output, id: 1PcQIfgDL17t6QR_O4e7ESKCOJ1OjCxCYawaeGF3-WSs
# title: Security Dilemma, id: 1HHb1p7XMnPPswVPK5yzVqUDFtOxucrTaqPTAs2ikTlA
# title: Math II, id: 0Byqwa9BQPtt3clZoVC1iM0dqUG8
# title: Port-CEGL-A01283502, id: 0Byqwa9BQPtt3aUZidnFlaTQwcFE
# title: Cuban Revolution, id: 1VbYzh45P0OtYOFi8rVSrLSruGyAOVhwUWec45A39gxg
# title: 404_KarenGuardado_Romanov's Dinasty Final Version.mp4, id: 0Byqwa9BQPtt3N2t0TDFPRHpwVHM
# title: B Positivo, id: 1ogcALM1-ErNCJJ6AmjZB64MJsohNDQUaLUxd195FMEc
# title: Dialogo de alemán, id: 1CIUo2Q3D_w3dmFjTtKJkTfIIoky-RVEokCmVdyxanDg
# title: Mapa conceptual y Tríptico de Proyecto #1/Bio-genera, id: 1WH5uoMc83iJKPncOmul48KJlo0DzTVgcqFfoR5YLVXg
# title: Investigacion de pintura ecologica a base de sabila terminada..docx, id: 1BH8pGFZCJ_D8sTgCTkcENkdpTLMcwNhzWVkUmk0HSqs
# title: Investigacion de pintura ecologica a base de sabila terminada..docx, id: 0Byqwa9BQPtt3NktRUEJIWl9SQ0k
# title: cédula, id: 15tLGZqQKgbRxeFT_3QACQIzzSudyPLMYIE8_-RKMDig
# title: Hypothyroidism, id: 1GxUdcTg1bL1n8gGkNMDkqkOP7_hWuLhBaFd4LEkqaEU
# title: UN , id: 1m-n7iViFDJ--P0aOJtFzUn0RSxLZmEgKjOr-EF1RsFU
# title: Planeación del proyecto, id: 1RtEUtgUr-UAhoPSr0gcWWVEs_sOnAPZBSu_bkA2MSfM
# title: Poemas de Español, id: 1iPtj82406olaq0H0-VtEXgIceylS5wlB-EYX2tPAio8
# title: Roles on the history project, id: 1_0azrTMoI6MlqMXC5pRqeLLPg9cSNkmDOtwVEDZQxtA
# title: 404_KarenGuardadoChacon_Storyboard&Script, id: 0Byqwa9BQPtt3VnduV2VZdGZ3Uk0
# title: Presidentes, id: 1HMuwu7j6eTMAbTRzroZ-q6PW4eBqIFbP8f7hwI157Kg
# title: podcast, id: 1kpAt2F1MrF3g7Jxncx95DXGGdyxv9VkHaTiFv85quDk
# title: nuremberg, id: 1kPcWJtHqL0ek0QtKyym3KNkV7A_g71POb28Ws00mtBE
# title: Nuremberg Trials, id: 1WCEWymjczk4Bgr14NFYj9Fq6TEa_1eyh1WViMcQZSjk
# title: 404 ensayo, id: 1mugaaw8UMK0YUhf4zEWnErXJVMbVOxrBV6EaGys2gR0
# title: La evolución de los sentimientos : tesis de español 2do parcial.docx, id: 0Byqwa9BQPtt3UGdzWFNSdGh6bVE
# title: cuna, id: 1zlyfup0smm2i8-OvX1ZBL0AYrWGdHLxhz6EjvxiKTnI
# title: Romanticismo.pdf, id: 0Byqwa9BQPtt3SnZXSk4tODcxTlU
# title: Neoclasico.docx, id: 0Byqwa9BQPtt3TFBBWU1fd3V4WWM
# title: Horizontal en blanco 4.docx, id: 0Byqwa9BQPtt3MVRDNDROckVsVGs
# title: IMG_3169.JPG, id: 0Byqwa9BQPtt3dEdzdWllQmF2cU0
# title: IMG_3168.JPG, id: 0Byqwa9BQPtt3Z1JHdzhsQ1ZyRXc
# title: IMG_3171.JPG, id: 0Byqwa9BQPtt3QVhrejVuUVR0Tkk
# title: IMG_3170.JPG, id: 0Byqwa9BQPtt3V2ZjbTc5Y3JpSmM
# title: monumentos y mausoleos 404, id: 1BNr6gyXSDLANaZ91Ldkl7DXTbKnFivOIMt8TZ8lOKho
# title:   Great Depression historia, id: 1_ROz3uGLyq8xPnVlW7tW-3I9D3Yv7ymJZDwLrKyfcDI
# title: Habilidades del Pensamiento, id: 1Jc_T8__FOfrlnLl4QYxeCpyx2Zu4bet7cOrgfx65Z4E
# title: Introduccion-404, id: 1kYeDBVoGLNIvBXC8jE4-bl7j7h1GZFntw3vaMbPZDCk
# title: Activity Week 5 Digestive system.docx - Gráfico de líneas 1, id: 1GYNnJIsEYhO6bNG3fPtkfAvsK7z-q4hz6CmUuAzQ7Ck
# title: 404_KarenGuardadoChacon_Quiz2.xcf, id: 0Byqwa9BQPtt3ellOLVVIb1l6T0k
# title: 404_KarenGuardadoChacon_Quiz2.png, id: 0Byqwa9BQPtt3SmpwMTY1a3RvbWs
# title: 404 Karen Guardado tesis de Edipo Rey, id: 1wr8jAWiNRGL0az_ht32ILjRElsQuxN0zQ7rVgL_ceRM
# title: Andrea Gzz y Karen Guardado 404, id: 1lF1goWtnQxWlx7bvWkwKalTpWFMQ1MUo-oNZg82P_Hk
# title: Tabla comp-edipo-hamlet-2da parte-17.doc, id: 0Byqwa9BQPtt3d1A5ZkVIRFdIV0E
# title: Digital Expression, id: 0Byqwa9BQPtt3YXN6UUV4TTFjNTA
# title: Documento sin título, id: 1pn9ucQybmjULB0XmJAaK2Nt7N1qCY9wsI9xAq9dFI1U
# title: Assignment_Report-4.pdf, id: 0Byqwa9BQPtt3UXNWbEZtMGZyUnM
# title: IMG_3886.JPG, id: 0Byqwa9BQPtt3Z005UlJ0QkhyRDg
# title: IMG_3887.JPG, id: 0Byqwa9BQPtt3RnBfSk1Vb25Ydk0
# title: LEARNSTER PRESENTATION, id: 18fTuHF13ZV5taelRLv7lEEAiMl53gNHw_ZtBLHwO3xo
# title: dialogo creatividad, id: 1u-n8EH4NasWOaFEFNk-SwHpPPjQJ0zUMew4cgWVsWLE
# title: Presentación sin título, id: 15cg9BXPcC4T7r8ycb4EPTB1mSlZKpCPxUms7pRlHxlo
# title: IMG_3723.JPG, id: 0Byqwa9BQPtt3NlJFd1BFYWw1SEk
# title: IMG_3722.JPG, id: 0Byqwa9BQPtt3RlpUWTNYbGkyN0U
# title: Assignment_Report-3.pdf, id: 0Byqwa9BQPtt3bm9sSUFobmEtblU
# title: Recombinant Proteins, id: 1fDnt8nYt7QpQs_S4O0vew6AKNzy3YjQ9nFUPa6E-SDk
# title: Mexico, id: 157BYtnU7jATzka8VOdUYi61tEQUnML6M-Gx2KQDMu10
# title: AllSpecialProductsActivity.JPG, id: 0Byqwa9BQPtt3RlNfY294c1NNdWc
# title: Trabajo de español, id: 1ki4XnhafBXtyDwSh4WmyQA-DiYcaIHm_29RuC4AxBig
# title: Group#407Team#1, id: 1Jj49tNLcUicMkFzjO0xYQOFUq8mdtlUpPZ2OlyWlGjI
# title: LEAC, id: 1BezQpItjnVyPWy_HcfSzziXR9Ge4Cbx00buVczfOlnw
# title: Extraterretrial Life- Group 407, id: 1CxqOUgnHS94vB5cnVqLrhcO2bsGAHHadVX0edUmb8bc

# %%
fid= '1_w6DM-SKyShdLXyOGmdjw2xtO2oCuh-p'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample EjemploSemanaTec.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1ok_fiBdplpFH-DfhEZSOWl2lR78BdwZb

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1ok_fiBdplpFH-DfhEZSOWl2lR78BdwZb'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('Ejemplo semana tec')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('Ejemplo semana tec').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '159CpKbyjyxZyrbskZOXZYLc-6k8MXqxpJQmjMj3SX2c',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('Ejemplo semana tec').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['6', '2', '1'], ['5', '8', '10']]
# ******************Data Frame*********************
#    0  1   2
# 0  6  2   1
# 1  5  8  10
